# %%
num= int(input("Dijite un numero"))
factorial = 1
for i in range (num):
  factorial *= num
  print(factorial," * ",num)
  num -= 1
print(factorial)
# Out:
#   File "<ipython-input-3-8930c294437f>", line 13
#     print("el factorial es " + str(res),)
#     ^
# IndentationError: unexpected indent
