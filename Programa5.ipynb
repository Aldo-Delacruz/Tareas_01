# %%
def pedido(val1,val2):
 
     if(val1+val2>10000):
        return [(val1+val2-10000),False]
     else:
        return [(val1+val2),True]



np= int(input("¿cuantos payasos quieres? "))
nj= int(input("¿cuantos juegos de mesa quieres? "))
pesop= 150 * np
pesoj= 170 * nj

res,status = pedido(pesop,pesoj)

if(status):
  print("El peso total es " + str(res)+"gr")
else:
  print("Error- se pasa por " + str(res)+"gr")
# Out:
# ¿cuantos payasos quieres? 10
# ¿cuantos juegos de mesa quieres? 20
# El peso total es 4900gr
