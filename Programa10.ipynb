# %%
def areaf(a,b):
      return (b*a**2)
def volumen(c,d):
    return (c*d)

radio= float(input("Cual es el radio del circulo: "))
altura= float(input("Cual es la altura del cilindro: "))

pi=3.1416
res = areaf(radio,pi)
print("El area es igual a : " + str(res),"cm2")
res1 = volumen(altura,areaf(radio,pi))
print("El volumen es igual a : " + str(res1),"cm3")
# Out:
# Cual es el radio del circulo: 1
# Cual es la altura del cilindro: 2
# El area es igual a : 3.1416 cm2
# El volumen es igual a : 6.2832 cm3
